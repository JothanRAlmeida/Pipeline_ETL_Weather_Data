# %%
path = '../data/weather_data.json'
import pandas as pd
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
with open(path) as file:
    data = json.load(file)

df = pd.json_normalize(data)

df.head()
# Out:
#                                                                     weather  \
# 0  [{'id': 804, 'main': 'Clouds', 'description': 'nublado', 'icon': '04n'}]
#
#        base  visibility          dt  timezone       id      name  cod  \
# 0  stations       10000  1779920967    -10800  3456905  Montanha  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -40.3633   -18.1269      23.02            23.68          23.02
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0          23.02           1017             88            1017
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all sys.country  \
# 0              996        1.98        77       2.56         100          BR
#
#    sys.sunrise  sys.sunset
# 0   1779872660  1779912793
